# %%
from pyHegel import *
from pyHegel.commands import *
from pyHegel.instruments import *

# %cd C:\Codes\QIQSS-CODE\CodePulse\v4
# %run -i pulsebuilder.py

SR = 1000

s = Segment(duration=0.1,
            offset=0,
            mark=(0, 0),
            waveform=Sine(**{'phase': 0, 'amp': 2, 'freq': 10}),
            envelope=None,
            sweep_dict={})

s1 = Segment(duration=1,
             waveform=Sine(10, 2, 0),
             envelope=GaussianFlatTop(1, 0.2, 0, 0.3),)
s1.mark = (0.1, 0.5)
s2 = Segment(duration=1, offset=1)
s2.to_ramp=True

p = Pulse(s1, s2)
seq = p.genSequence(3,
                    compensate=-1)
#plotPulse(p, SR, highlight=[0, 1])
plotPulse(seq, SR, superpose=True, highlight=[1])
# Out:
# C:\Codes\QIQSS-CODE\CodePulse\v4
# Running under ipython
# Running under ipython remote kernel
# Qt loop already working
# 1
# 1
# 1
# Segment(duration=1, offset=0, mark=(0.1, 0.5), waveform=Sine(**{'phase': 0, 'amp': 2, 'freq': 10}), envelope=GaussianFlatTop(**{'mu': 0, 'amp': 1, 'sigma': 0.2, 'flat_perc': 0.3}), sweep_dict={})

# %%
# %cd C:\Codes\QIQSS-CODE\CodePulse\v4\
# %run -i pulsebuilder.py

## Code generated from PulseBuilder ##
SR = 1000.0
segment_13 = Segment(duration=0.1, offset=0, mark=(0, 0), waveform=Sine(**{'phase': 0, 'amp': 2, 'freq': 10}), envelope=None, sweep_dict={}) 
segment_14 = Segment(duration=0.1, offset=0, mark=(0, 0), waveform=Sine(**{'phase': 0, 'amp': 2, 'freq': 10}), envelope=None, sweep_dict={'offset': (3.0, 10.0)}) 
segment_15 = Segment(duration=0.1, offset=0, mark=(0, 0), waveform=Sine(**{'phase': 0, 'amp': 2, 'freq': 10}), envelope=None, sweep_dict={}) 
segment_16 = Segment(duration=0.1, offset=0, mark=(0, 0), waveform=Sine(**{'phase': 0, 'amp': 2, 'freq': 10}), envelope=None, sweep_dict={}) 
pulse = Pulse(*[segment_13, segment_14, segment_15, segment_16])
sequence = pulse.genSequence(nb_rep=10, compensate=0.0)
plotPulse(sequence, SR)
pb.loadPulse(pulse)
# Out:
# [Error 2] The system cannot find the file specified: u'C:\\Codes\\QIQSS-CODE\\CodePulse\\v4%run -i pulsebuilder.py'
# C:\Codes\QIQSS-CODE\CodePulse\v4
# NameErrorTraceback (most recent call last)
# <ipython-input-4-a84bf4908557> in <module>()
#       3 ## Code generated from PulseBuilder ##
#       4 SR = 1000.0
# ----> 5 segment_13 = Segment(duration=0.1, offset=0, mark=(0, 0), waveform=Sine(**{'phase': 0, 'amp': 2, 'freq': 10}), envelope=None, sweep_dict={})
#       6 segment_14 = Segment(duration=0.1, offset=0, mark=(0, 0), waveform=Sine(**{'phase': 0, 'amp': 2, 'freq': 10}), envelope=None, sweep_dict={'offset': (3.0, 10.0)})
#       7 segment_15 = Segment(duration=0.1, offset=0, mark=(0, 0), waveform=Sine(**{'phase': 0, 'amp': 2, 'freq': 10}), envelope=None, sweep_dict={})
#
# NameError: name 'Segment' is not defined

# %%
# Out:
# C:\Codes\QIQSS-CODE\CodePulse\v4
# Running under ipython
# Running under ipython remote kernel
# resetting qApp
# Qt loop already working

# %%
# %run pulsebuilder
# Out:
# ERROR:root:File `u'pulsebuilder.py'` not found.
